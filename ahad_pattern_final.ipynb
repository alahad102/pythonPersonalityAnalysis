# %%
import numpy as np
import pandas as pd

df1 = pd.read_csv('Dataset_New.csv')
df1.head()
# Out:
#              Timestamp  Score           ID  Gender  Height  Weight   CGPA  \
# 0  2019-03-27 12:37:00  0 / 1  151340905.0  Female  158.50    58.0  3.930
# 1  2019-03-29 01:19:00  0 / 1  151341043.0    Male  176.78    70.0  3.845
# 2  2019-03-27 12:52:00  0 / 1  151340925.0    Male  164.59    60.0  3.830
# 3  2019-03-27 12:45:00  0 / 1  151340912.0    Male  178.31    68.0  3.800
# 4  2019-03-27 12:39:00  0 / 1  151340898.0  Female  167.64    60.0  3.770
#
#   Daily spent time in social media (hour)    Hometown  \
# 0                     2019-05-02 00:00:00     Comilla
# 1                     2019-05-02 00:00:00  Munshiganj
# 2                            Below 1 hour     Barisal
# 3                     2019-05-02 00:00:00     Barisal
# 4                     2019-05-02 00:00:00       Dhaka
#
#   How many days in a week you feel more energetic       ...        \
# 0                             2019-02-01 00:00:00       ...
# 1                                               2       ...
# ...

# %%
df2 = pd.read_csv('qs1 (c).csv')
df2.head()
# Out:
#           id    hometown fastfood_frequency excercise      food_portions  \
# 0  151340905     comilla                yes        no     carb, vitamins
# 1  151341043  munshiganj                yes        no     carb, protiens
# 2  151340925     barisal              maybe     maybe      carb,protiens
# 3  151340898       dhaka                yes        no  protiens, vitamin
# 4  151341027       pabna                 no        no               carb
#
#   wakeup_habit  gender
# 0           lr  female
# 1           lr    male
# 2           er    male
# 3           lr  female
# 4           lr    male

# %%
columns = [
"ID",
"Gender", 
"Height",
"Weight",

]

# Get names of indexes for which column Age has value 30

df1 = df1[columns].copy()
df1.head()
#df1.to_csv('cleaned2.csv')
# Out:
#             ID  Gender  Height  Weight
# 0  151340905.0  Female  158.50    58.0
# 1  151341043.0    Male  176.78    70.0
# 2  151340925.0    Male  164.59    60.0
# 3  151340912.0    Male  178.31    68.0
# 4  151340898.0  Female  167.64    60.0

# %%
df1.to_csv('New.csv')

# %%
df1 = pd.read_csv('New.csv')
df1.head()
# Out:
#    Unnamed: 0           ID  Gender  Height  Weight
# 0           0  151340905.0  Female  158.50    58.0
# 1           1  151341043.0    Male  176.78    70.0
# 2           2  151340925.0    Male  164.59    60.0
# 3           3  151340912.0    Male  178.31    68.0
# 4           4  151340898.0  Female  167.64    60.0

# %%
df1.drop("Unnamed: 0",axis=1,inplace=True)
df1.head()
# Out:
#             ID  Gender  Height  Weight
# 0  151340905.0  Female  158.50    58.0
# 1  151341043.0    Male  176.78    70.0
# 2  151340925.0    Male  164.59    60.0
# 3  151340912.0    Male  178.31    68.0
# 4  151340898.0  Female  167.64    60.0

# %%
columns = [
"id",
"fastfood_frequency", 
"excercise",
"wakeup_habit",

]

# Get names of indexes for which column Age has value 30

df2 = df2[columns].copy()
df2.head()
#df1.to_csv('cleaned2.csv')
# Out:
#           id fastfood_frequency excercise wakeup_habit
# 0  151340905                yes        no           lr
# 1  151341043                yes        no           lr
# 2  151340925              maybe     maybe           er
# 3  151340898                yes        no           lr
# 4  151341027                 no        no           lr

# %%
df2
# Out:
#            id fastfood_frequency excercise wakeup_habit
# 0   151340905                yes        no           lr
# 1   151341043                yes        no           lr
# 2   151340925              maybe     maybe           er
# 3   151340898                yes        no           lr
# 4   151341027                 no        no           lr
# 5   151341011                 no        no           lr
# 6   151341004                 no       yes           er
# 7   151341004                 no       yes           er
# 8   151341004                 no       yes           er
# 9   151341004                 no       yes           er
# 10  151340923                 no       yes           lr
# 11  151340944                yes     maybe           lr
# 12  151340928                yes        no           lr
# 13  151341009              maybe        no           lr
# 14  151340910                yes     maybe           lr
# 15  151341035                yes        no           lr
# ...

# %%
df1 = pd.read_csv('New.csv')
df1.head()
# Out:
#    Unnamed: 0           ID  Gender  Height  Weight
# 0           0  151340905.0  Female  158.50    58.0
# 1           1  151341043.0    Male  176.78    70.0
# 2           2  151340925.0    Male  164.59    60.0
# 3           3  151340912.0    Male  178.31    68.0
# 4           4  151340898.0  Female  167.64    60.0

# %%
df1 = pd.read_csv('new1.csv')
df1.head()
# Out:
#    Unnamed: 0           id  Gender  Height  Weight
# 0           0  151340905.0  Female  158.50    58.0
# 1           1  151341043.0    Male  176.78    70.0
# 2           2  151340925.0    Male  164.59    60.0
# 3           3  151340912.0    Male  178.31    68.0
# 4           4  151340898.0  Female  167.64    60.0

# %%
MainDataset = pd.merge(df1,df2)
MainDataset.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight fastfood_frequency  \
# 0           0  151340905.0  Female  158.5000    58.0                yes
# 1           1  151341043.0    Male  176.7800    70.0                yes
# 2           2  151340925.0    Male  164.5900    60.0              maybe
# 3           4  151340898.0  Female  167.6400    60.0                yes
# 4           5  151341027.0    Male  182.5752    70.0                 no
#
#   excercise wakeup_habit
# 0        no           lr
# 1        no           lr
# 2     maybe           er
# 3        no           lr
# 4        no           lr

# %%
len(MainDataset)
# Out:
# 79

# %%
MainDataset
# Out:
#     Unnamed: 0           id  Gender    Height  Weight fastfood_frequency  \
# 0            0  151340905.0  Female  158.5000    58.0                yes
# 1            1  151341043.0    Male  176.7800    70.0                yes
# 2            2  151340925.0    Male  164.5900    60.0              maybe
# 3            4  151340898.0  Female  167.6400    60.0                yes
# 4            5  151341027.0    Male  182.5752    70.0                 no
# 5            6  151341011.0    Male  161.5440    59.0                 no
# 6            7  151341004.0    Male  170.6880    70.0                 no
# 7            7  151341004.0    Male  170.6880    70.0                 no
# 8            7  151341004.0    Male  170.6880    70.0                 no
# 9            7  151341004.0    Male  170.6880    70.0                 no
# 10         103  151341004.0     NaN  173.7360     NaN                 no
# 11         103  151341004.0     NaN  173.7360     NaN                 no
# ...

# %%
MainDataset.drop("Unnamed: 0",axis=1,inplace=True)
MainDataset.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  158.5000    58.0                yes        no
# 1  151341043.0    Male  176.7800    70.0                yes        no
# 2  151340925.0    Male  164.5900    60.0              maybe     maybe
# 3  151340898.0  Female  167.6400    60.0                yes        no
# 4  151341027.0    Male  182.5752    70.0                 no        no
#
#   wakeup_habit
# 0           lr
# 1           lr
# 2           er
# 3           lr
# 4           lr

# %%
MainDataset['BMI']=MainDataset[['Weight']]
MainDataset.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  158.5000    58.0                yes        no
# 1  151341043.0    Male  176.7800    70.0                yes        no
# 2  151340925.0    Male  164.5900    60.0              maybe     maybe
# 3  151340898.0  Female  167.6400    60.0                yes        no
# 4  151341027.0    Male  182.5752    70.0                 no        no
#
#   wakeup_habit   BMI
# 0           lr  58.0
# 1           lr  70.0
# 2           er  60.0
# 3           lr  60.0
# 4           lr  70.0

# %%
MainDataset['BMI']=MainDataset['BMI'].div(MainDataset['Height'],axis=0)
MainDataset.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  158.5000    58.0                yes        no
# 1  151341043.0    Male  176.7800    70.0                yes        no
# 2  151340925.0    Male  164.5900    60.0              maybe     maybe
# 3  151340898.0  Female  167.6400    60.0                yes        no
# 4  151341027.0    Male  182.5752    70.0                 no        no
#
#   wakeup_habit       BMI
# 0           lr  0.365931
# 1           lr  0.395972
# 2           er  0.364542
# 3           lr  0.357910
# 4           lr  0.383404

# %%
MainDataset['BMI']=MainDataset['BMI'].mul(MainDataset['Height'],axis=0)
MainDataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-243eb4db4cef> in <module>()
# ----> 1 MainDataset['BMI']=MainDataset['BMI'].mul(MainDataset['Height'],axis=0)
#       2 MainDataset.head()
#
# NameError: name 'MainDataset' is not defined

# %%
import numpy as np
import pandas as pd

df1 = pd.read_csv('new1.csv')
df1.head()
# Out:
#    Unnamed: 0           id  Gender  Height  Weight
# 0           0  151340905.0  Female  158.50    58.0
# 1           1  151341043.0    Male  176.78    70.0
# 2           2  151340925.0    Male  164.59    60.0
# 3           3  151340912.0    Male  178.31    68.0
# 4           4  151340898.0  Female  167.64    60.0

# %%
df2 = pd.read_csv('qs1 (c).csv')
df2.head()
# Out:
#           id    hometown fastfood_frequency excercise      food_portions  \
# 0  151340905     comilla                yes        no     carb, vitamins
# 1  151341043  munshiganj                yes        no     carb, protiens
# 2  151340925     barisal              maybe     maybe      carb,protiens
# 3  151340898       dhaka                yes        no  protiens, vitamin
# 4  151341027       pabna                 no        no               carb
#
#   wakeup_habit  gender
# 0           lr  female
# 1           lr    male
# 2           er    male
# 3           lr  female
# 4           lr    male

# %%
MainDataset = pd.merge(df1,df2)
MainDataset.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight    hometown  \
# 0           0  151340905.0  Female  158.5000    58.0     comilla
# 1           1  151341043.0    Male  176.7800    70.0  munshiganj
# 2           2  151340925.0    Male  164.5900    60.0     barisal
# 3           4  151340898.0  Female  167.6400    60.0       dhaka
# 4           5  151341027.0    Male  182.5752    70.0       pabna
#
#   fastfood_frequency excercise      food_portions wakeup_habit  gender
# 0                yes        no     carb, vitamins           lr  female
# 1                yes        no     carb, protiens           lr    male
# 2              maybe     maybe      carb,protiens           er    male
# 3                yes        no  protiens, vitamin           lr  female
# 4                 no        no               carb           lr    male

# %%
MainDataset.drop("Unnamed: 0",axis=1,inplace=True)
MainDataset.head()
# Out:
#             id  Gender    Height  Weight    hometown fastfood_frequency  \
# 0  151340905.0  Female  158.5000    58.0     comilla                yes
# 1  151341043.0    Male  176.7800    70.0  munshiganj                yes
# 2  151340925.0    Male  164.5900    60.0     barisal              maybe
# 3  151340898.0  Female  167.6400    60.0       dhaka                yes
# 4  151341027.0    Male  182.5752    70.0       pabna                 no
#
#   excercise      food_portions wakeup_habit  gender
# 0        no     carb, vitamins           lr  female
# 1        no     carb, protiens           lr    male
# 2     maybe      carb,protiens           er    male
# 3        no  protiens, vitamin           lr  female
# 4        no               carb           lr    male

# %%
MainDataset.to_csv('newDataset.csv')

# %%
columns = [
"id",
"fastfood_frequency", 
"excercise",
"wakeup_habit",

]

# Get names of indexes for which column Age has value 30

df2 = df2[columns].copy()
df2.head()
#df1.to_csv('cleaned2.csv')
# Out:
#           id fastfood_frequency excercise wakeup_habit
# 0  151340905                yes        no           lr
# 1  151341043                yes        no           lr
# 2  151340925              maybe     maybe           er
# 3  151340898                yes        no           lr
# 4  151341027                 no        no           lr

# %%
MainDataset = pd.merge(df1,df2)
MainDataset.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight fastfood_frequency  \
# 0           0  151340905.0  Female  158.5000    58.0                yes
# 1           1  151341043.0    Male  176.7800    70.0                yes
# 2           2  151340925.0    Male  164.5900    60.0              maybe
# 3           4  151340898.0  Female  167.6400    60.0                yes
# 4           5  151341027.0    Male  182.5752    70.0                 no
#
#   excercise wakeup_habit
# 0        no           lr
# 1        no           lr
# 2     maybe           er
# 3        no           lr
# 4        no           lr

# %%
MainDataset.drop("Unnamed: 0",axis=1,inplace=True)
MainDataset.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  158.5000    58.0                yes        no
# 1  151341043.0    Male  176.7800    70.0                yes        no
# 2  151340925.0    Male  164.5900    60.0              maybe     maybe
# 3  151340898.0  Female  167.6400    60.0                yes        no
# 4  151341027.0    Male  182.5752    70.0                 no        no
#
#   wakeup_habit
# 0           lr
# 1           lr
# 2           er
# 3           lr
# 4           lr

# %%
MainDataset.to_csv('newDataset1.csv')

# %%
df1=pd.read_csv('newDataset1.csv')
df1.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-3683d2f42f02> in <module>()
#       1 df1=pd.read_csv('newDataset1.csv')
# ----> 2 df1.read()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
df1 = pd.read_csv('newDataset1.csv')
df1.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight fastfood_frequency  \
# 0           0  151340905.0  Female  158.5000    58.0                yes
# 1           1  151341043.0    Male  176.7800    70.0                yes
# 2           2  151340925.0    Male  164.5900    60.0              maybe
# 3           3  151340898.0  Female  167.6400    60.0                yes
# 4           4  151341027.0    Male  182.5752    70.0                 no
#
#   excercise wakeup_habit
# 0        no           lr
# 1        no           lr
# 2     maybe           er
# 3        no           lr
# 4        no           lr

# %%
df1.drop("Unnamed: 0",axis=1,inplace=True)
df1.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  158.5000    58.0                yes        no
# 1  151341043.0    Male  176.7800    70.0                yes        no
# 2  151340925.0    Male  164.5900    60.0              maybe     maybe
# 3  151340898.0  Female  167.6400    60.0                yes        no
# 4  151341027.0    Male  182.5752    70.0                 no        no
#
#   wakeup_habit
# 0           lr
# 1           lr
# 2           er
# 3           lr
# 4           lr

# %%
df1['Height'] = df1['Height']/100
df1.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                yes        no
# 1  151341043.0    Male  1.767800    70.0                yes        no
# 2  151340925.0    Male  1.645900    60.0              maybe     maybe
# 3  151340898.0  Female  1.676400    60.0                yes        no
# 4  151341027.0    Male  1.825752    70.0                 no        no
#
#   wakeup_habit
# 0           lr
# 1           lr
# 2           er
# 3           lr
# 4           lr

# %%
df1['Height2'] = df1['Height'] * df1['Height']
df1['Height2']
# Out:
# 0     2.512225
# 1     3.125117
# 2     2.708987
# 3     2.810317
# 4     3.333370
# 5     2.609646
# 6     2.913439
# 7     2.913439
# 8     2.913439
# 9     2.913439
# 10    3.018420
# 11    3.018420
# 12    3.018420
# 13    3.018420
# 14    2.810317
# 15    3.233955
# 16    3.456922
# 17    2.709053
# 18    3.333370
# 19    2.810317
# 20    3.233955
# 21    2.609646
# 22    3.344509
# 23    2.709053
# 24    3.333370
# 25    2.709053
# 26    2.609646
# 27    2.609646
# 28    2.810317
# 29    2.425893
#         ...
# 49    2.512098
# 50    3.333370
# 51    2.709053
# 52    3.456922
# 53    3.125258
# 54    2.810317
# 55    2.983220
# 56    2.810317
# 57    2.416408
# 58    3.333370
# 59    2.512098
# 60    2.896123
# 61    3.071607
# 62    2.512098
# 63    1.561700
# 64    2.913439
# 65    3.125258
# 66    2.709053
# 67    3.125258
# 68    2.421148
# 69    2.913439
# 70    3.344509
# 71    2.810317
# 72    3.333370
# 73    2.608225
# 74    3.125258
# 75    3.333370
# 76    2.913439
# ...

# %%
df1.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                yes        no
# 1  151341043.0    Male  1.767800    70.0                yes        no
# 2  151340925.0    Male  1.645900    60.0              maybe     maybe
# 3  151340898.0  Female  1.676400    60.0                yes        no
# 4  151341027.0    Male  1.825752    70.0                 no        no
#
#   wakeup_habit   Height2
# 0           lr  2.512225
# 1           lr  3.125117
# 2           er  2.708987
# 3           lr  2.810317
# 4           lr  3.333370

# %%
df1['BMI'] = df1['Weight'] / (df1['Height'] * df1['Height'])
df1.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                yes        no
# 1  151341043.0    Male  1.767800    70.0                yes        no
# 2  151340925.0    Male  1.645900    60.0              maybe     maybe
# 3  151340898.0  Female  1.676400    60.0                yes        no
# 4  151341027.0    Male  1.825752    70.0                 no        no
#
#   wakeup_habit   Height2        BMI
# 0           lr  2.512225  23.087104
# 1           lr  3.125117  22.399163
# 2           er  2.708987  22.148502
# 3           lr  2.810317  21.349905
# 4           lr  3.333370  20.999767

# %%
df1.drop("Height2",axis=1,inplace=True)
df1.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                yes        no
# 1  151341043.0    Male  1.767800    70.0                yes        no
# 2  151340925.0    Male  1.645900    60.0              maybe     maybe
# 3  151340898.0  Female  1.676400    60.0                yes        no
# 4  151341027.0    Male  1.825752    70.0                 no        no
#
#   wakeup_habit        BMI
# 0           lr  23.087104
# 1           lr  22.399163
# 2           er  22.148502
# 3           lr  21.349905
# 4           lr  20.999767

# %%
df2=df1
df2.head()
# Out:
#             id  Gender    Height  Weight fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                yes        no
# 1  151341043.0    Male  1.767800    70.0                yes        no
# 2  151340925.0    Male  1.645900    60.0              maybe     maybe
# 3  151340898.0  Female  1.676400    60.0                yes        no
# 4  151341027.0    Male  1.825752    70.0                 no        no
#
#   wakeup_habit        BMI
# 0           lr  23.087104
# 1           lr  22.399163
# 2           er  22.148502
# 3           lr  21.349905
# 4           lr  20.999767

# %%
fastfood_frequency = {'yes': 1, 'maybe':2,'no':3} 
df1.fastfood_frequency= [fastfood_frequency[item] for item in df1.fastfood_frequency] 
df1.tail(10)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency excercise  \
# 69  151340903.0    Male  1.706880    68.0                   2     maybe
# 70  151340894.0    Male  1.828800    73.0                   1     maybe
# 71  151340920.0    Male  1.676400    82.0                   1        no
# 72  151341022.0    Male  1.825752    50.0                   1        no
# 73  131440910.0  Female  1.615000    42.0                   1     maybe
# 74  141340900.0    Male  1.767840    70.0                   1        no
# 75  121440946.0    Male  1.825752    90.0                   2     maybe
# 76  141440962.0    Male  1.706880    64.0                   1       yes
# 77  151340904.0    Male  1.786450    67.0                   2       yes
# 78  151340916.0    Male  1.706880    55.0                   3     maybe
#
#    wakeup_habit        BMI
# 69           lr  23.340112
# 70           er  21.826818
# 71           lr  29.178203
# 72           lr  14.999833
# 73           er  16.102905
# ...

# %%
df1.head()
# Out:
#             id  Gender    Height  Weight  fastfood_frequency excercise  \
# 0  151340905.0  Female  1.585000    58.0                   1        no
# 1  151341043.0    Male  1.767800    70.0                   1        no
# 2  151340925.0    Male  1.645900    60.0                   2     maybe
# 3  151340898.0  Female  1.676400    60.0                   1        no
# 4  151341027.0    Male  1.825752    70.0                   3        no
#
#   wakeup_habit        BMI
# 0           lr  23.087104
# 1           lr  22.399163
# 2           er  22.148502
# 3           lr  21.349905
# 4           lr  20.999767

# %%
excercise = {'yes': 3, 'maybe':2,'no':1} 
df1.excercise= [excercise[item] for item in df1.excercise] 
df1.tail(10)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 69  151340903.0    Male  1.706880    68.0                   2          2
# 70  151340894.0    Male  1.828800    73.0                   1          2
# 71  151340920.0    Male  1.676400    82.0                   1          1
# 72  151341022.0    Male  1.825752    50.0                   1          1
# 73  131440910.0  Female  1.615000    42.0                   1          2
# 74  141340900.0    Male  1.767840    70.0                   1          1
# 75  121440946.0    Male  1.825752    90.0                   2          2
# 76  141440962.0    Male  1.706880    64.0                   1          3
# 77  151340904.0    Male  1.786450    67.0                   2          3
# 78  151340916.0    Male  1.706880    55.0                   3          2
#
#    wakeup_habit        BMI
# 69           lr  23.340112
# 70           er  21.826818
# 71           lr  29.178203
# 72           lr  14.999833
# ...

# %%
wakeup_habit = {'er': 3, 'lr':1} 
df1.wakeup_habit= [wakeup_habit[item] for item in df1.wakeup_habit] 
df1.tail(10)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 69  151340903.0    Male  1.706880    68.0                   2          2
# 70  151340894.0    Male  1.828800    73.0                   1          2
# 71  151340920.0    Male  1.676400    82.0                   1          1
# 72  151341022.0    Male  1.825752    50.0                   1          1
# 73  131440910.0  Female  1.615000    42.0                   1          2
# 74  141340900.0    Male  1.767840    70.0                   1          1
# 75  121440946.0    Male  1.825752    90.0                   2          2
# 76  141440962.0    Male  1.706880    64.0                   1          3
# 77  151340904.0    Male  1.786450    67.0                   2          3
# 78  151340916.0    Male  1.706880    55.0                   3          2
#
#     wakeup_habit        BMI
# 69             1  23.340112
# 70             3  21.826818
# 71             1  29.178203
# 72             1  14.999833
# ...

# %%
df1
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 0   151340905.0  Female  1.585000    58.0                   1          1
# 1   151341043.0    Male  1.767800    70.0                   1          1
# 2   151340925.0    Male  1.645900    60.0                   2          2
# 3   151340898.0  Female  1.676400    60.0                   1          1
# 4   151341027.0    Male  1.825752    70.0                   3          1
# 5   151341011.0    Male  1.615440    59.0                   3          1
# 6   151341004.0    Male  1.706880    70.0                   3          3
# 7   151341004.0    Male  1.706880    70.0                   3          3
# 8   151341004.0    Male  1.706880    70.0                   3          3
# 9   151341004.0    Male  1.706880    70.0                   3          3
# 10  151341004.0     NaN  1.737360     NaN                   3          3
# 11  151341004.0     NaN  1.737360     NaN                   3          3
# ...

# %%
df1.dropna(inplace=True)
len(df1)
# Out:
# 75

# %%
df1
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 0   151340905.0  Female  1.585000    58.0                   1          1
# 1   151341043.0    Male  1.767800    70.0                   1          1
# 2   151340925.0    Male  1.645900    60.0                   2          2
# 3   151340898.0  Female  1.676400    60.0                   1          1
# 4   151341027.0    Male  1.825752    70.0                   3          1
# 5   151341011.0    Male  1.615440    59.0                   3          1
# 6   151341004.0    Male  1.706880    70.0                   3          3
# 7   151341004.0    Male  1.706880    70.0                   3          3
# 8   151341004.0    Male  1.706880    70.0                   3          3
# 9   151341004.0    Male  1.706880    70.0                   3          3
# 14  151340923.0    Male  1.676400    67.0                   3          3
# 15  151340944.0    Male  1.798320    62.0                   1          2
# ...

# %%
df1.head()
# Out:
#             id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 0  151340905.0  Female  1.585000    58.0                   1          1
# 1  151341043.0    Male  1.767800    70.0                   1          1
# 2  151340925.0    Male  1.645900    60.0                   2          2
# 3  151340898.0  Female  1.676400    60.0                   1          1
# 4  151341027.0    Male  1.825752    70.0                   3          1
#
#    wakeup_habit        BMI
# 0             1  23.087104
# 1             1  22.399163
# 2             3  22.148502
# 3             1  21.349905
# 4             1  20.999767

# %%
df1.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df1.Height.unique()
# Out:
# array([1.585   , 1.7678  , 1.6459  , 1.6764  , 1.825752, 1.61544 ,
#        1.70688 , 1.79832 , 1.85928 , 1.64592 , 1.8288  , 1.557528,
#        1.73736 , 1.76784 , 1.58496 , 1.252728, 1.7272  , 1.55448 ,
#        1.7018  , 1.7526  , 1.24968 , 1.556004, 1.615   , 1.78645 ])

# %%
df1.Weight.unique()
# Out:
# array([ 58.,  70.,  60.,  59.,  67.,  62.,  65.,  49., 110.,  50.,  74.,
#         47.,  85.,  54.,  61.,  45.,  80.,  56.,  75.,  96.,  40.,  63.,
#         55.,  48.,  95.,  64.,  46.,  82.,  89.,  90.,  72.,  57.,  51.,
#         78.,  68.,  73.,  42.])

# %%
df1.BMI.unique()
# Out:
# array([23.08710406, 22.39916252, 22.14850208, 21.34990496, 20.9997667 ,
#        22.60842701, 24.02658575, 23.8407272 , 19.1715727 , 18.80285346,
#        18.08750379, 32.99963339, 17.79158747, 22.88219968, 18.01010287,
#        25.41478848, 19.93316744, 17.99980003, 22.14796382, 23.37481436,
#        17.24371551, 21.70573671, 32.97754043, 20.6714329 , 24.84743864,
#        34.15984793, 14.23326997, 18.89979003, 17.59854557, 19.9036805 ,
#        25.74277045, 19.2212686 , 17.93469705, 22.19975337, 18.39329655,
#        27.48109351, 20.54054927, 23.19141859, 20.47830757, 29.31191972,
#        22.29212216, 26.23783157, 25.87478466, 26.69970338, 24.58834683,
#        28.79762002, 22.06156846, 19.44208041, 25.61988595, 20.69186931,
#        22.49975004, 21.89404855, 22.44379628, 17.90593793, 22.69019577,
#        32.6567181 , 15.78889921, 20.79828113, 24.95793735, 29.73795351,
#        23.34011187, 21.82681834, 29.17820344, 14.99983336, 16.10290523,
# ...

# %%
df1.excercise.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
import numpy as np

conditions = [
    (df1['BMI'] <= 18.5),
    (df1['BMI'] >= 18.5) & (df1['BMI'] <= 24.9),
    (df1['BMI'] >= 25) & (df1['BMI'] <= 29.9)]
choices = ['Underweight', 'Normal', 'Overweight']
df1['Physical_Condition'] = np.select(conditions, choices, default='Obese')
df1.head()
# Out:
#             id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 0  151340905.0  Female  1.585000    58.0                   1          1
# 1  151341043.0    Male  1.767800    70.0                   1          1
# 2  151340925.0    Male  1.645900    60.0                   2          2
# 3  151340898.0  Female  1.676400    60.0                   1          1
# 4  151341027.0    Male  1.825752    70.0                   3          1
#
#    wakeup_habit        BMI Physical_Condition
# 0             1  23.087104             Normal
# 1             1  22.399163             Normal
# 2             3  22.148502             Normal
# 3             1  21.349905             Normal
# 4             1  20.999767             Normal

# %%
df1.sample(15)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 40  151341014.0    Male  1.825752    74.0                   1          2
# 21  151340939.0  Female  1.615440    47.0                   1          2
# 22  151340897.0    Male  1.828800    85.0                   3          1
# 30  151341036.0  Female  1.645920    56.0                   1          1
# 5   151341011.0    Male  1.615440    59.0                   3          1
# 61  151340906.0    Male  1.752600    55.0                   3          2
# 25  151340982.0  Female  1.645920    60.0                   3          1
# 69  151340903.0    Male  1.706880    68.0                   2          2
# 0   151340905.0  Female  1.585000    58.0                   1          1
# 52  151340985.0    Male  1.859280    85.0                   1          1
# 62  151341038.0  Female  1.584960    57.0                   1          1
# 48  151340901.0    Male  1.767840    82.0                   1          3
# ...

# %%
df3=df1

# %%
Physical_Condition = {'Normal': 3, 'Underweight':2,'Overweight':1 } 
df1.Physical_Condition= [Physical_Condition[item] for item in df1.Physical_Condition] 
df1.tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ff827f61adc1> in <module>()
#       1 Physical_Condition = {'Normal': 3, 'Underweight':2,'Overweight':1 }
# ----> 2 df1.Physical_Condition= [Physical_Condition[item] for item in df1.Physical_Condition]
#       3 df1.tail(10)
#
# <ipython-input-39-ff827f61adc1> in <listcomp>(.0)
#       1 Physical_Condition = {'Normal': 3, 'Underweight':2,'Overweight':1 }
# ----> 2 df1.Physical_Condition= [Physical_Condition[item] for item in df1.Physical_Condition]
#       3 df1.tail(10)
#
# KeyError: 'Obese'

# %%
df1.Physical_Condition.unique()
# Out:
# array(['Normal', 'Underweight', 'Obese', 'Overweight'], dtype=object)

# %%
Physical_Condition = {'Normal': 4, 'Underweight':3,'Overweight':2 , 'Obese':1} 
df1.Physical_Condition= [Physical_Condition[item] for item in df1.Physical_Condition] 
df1.tail(10)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 69  151340903.0    Male  1.706880    68.0                   2          2
# 70  151340894.0    Male  1.828800    73.0                   1          2
# 71  151340920.0    Male  1.676400    82.0                   1          1
# 72  151341022.0    Male  1.825752    50.0                   1          1
# 73  131440910.0  Female  1.615000    42.0                   1          2
# 74  141340900.0    Male  1.767840    70.0                   1          1
# 75  121440946.0    Male  1.825752    90.0                   2          2
# 76  141440962.0    Male  1.706880    64.0                   1          3
# 77  151340904.0    Male  1.786450    67.0                   2          3
# 78  151340916.0    Male  1.706880    55.0                   3          2
#
#     wakeup_habit        BMI  Physical_Condition
# 69             1  23.340112                   4
# 70             3  21.826818                   4
# ...

# %%
Gender = {'Normal': 4, 'Underweight':3,'Overweight':2 , 'Obese':1} 
df1.Gender= [Gender[item] for item in df1.Gender] 
df1.tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-cf214f1ac310> in <module>()
#       1 Gender = {'Normal': 4, 'Underweight':3,'Overweight':2 , 'Obese':1}
# ----> 2 df1.Gender= [Gender[item] for item in df1.Gender]
#       3 df1.tail(10)
#
# <ipython-input-44-cf214f1ac310> in <listcomp>(.0)
#       1 Gender = {'Normal': 4, 'Underweight':3,'Overweight':2 , 'Obese':1}
# ----> 2 df1.Gender= [Gender[item] for item in df1.Gender]
#       3 df1.tail(10)
#
# KeyError: 'Female'

# %%
Gender = {'Male': 2, 'Female': 1} 
df1.Gender= [Gender[item] for item in df1.Gender] 
df1.tail(10)
# Out:
#              id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 69  151340903.0       2  1.706880    68.0                   2          2
# 70  151340894.0       2  1.828800    73.0                   1          2
# 71  151340920.0       2  1.676400    82.0                   1          1
# 72  151341022.0       2  1.825752    50.0                   1          1
# 73  131440910.0       1  1.615000    42.0                   1          2
# 74  141340900.0       2  1.767840    70.0                   1          1
# 75  121440946.0       2  1.825752    90.0                   2          2
# 76  141440962.0       2  1.706880    64.0                   1          3
# 77  151340904.0       2  1.786450    67.0                   2          3
# 78  151340916.0       2  1.706880    55.0                   3          2
#
#     wakeup_habit        BMI  Physical_Condition
# 69             1  23.340112                   4
# 70             3  21.826818                   4
# ...

# %%
df1.to_csv('output.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv('output.csv')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4e6893d2b6af> in <module>()
#       4 import seaborn as sns
#       5
# ----> 6 df1=pd.read('output.csv')
#       7 df1.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df.groupby('fastfood_frequency')['wakeup_habit'].count().plot(kind='bar')
plt.ylabel('wakeup_habit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf02e3a21bbc> in <module>()
# ----> 1 df.groupby('fastfood_frequency')['wakeup_habit'].count().plot(kind='bar')
#       2 plt.ylabel('wakeup_habit')
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv('output.csv')
df1.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight  fastfood_frequency  \
# 0           0  151340905.0       1  1.585000    58.0                   1
# 1           1  151341043.0       2  1.767800    70.0                   1
# 2           2  151340925.0       2  1.645900    60.0                   2
# 3           3  151340898.0       1  1.676400    60.0                   1
# 4           4  151341027.0       2  1.825752    70.0                   3
#
#    excercise  wakeup_habit        BMI  Physical_Condition
# 0          1             1  23.087104                   4
# 1          1             1  22.399163                   4
# 2          2             3  22.148502                   4
# 3          1             1  21.349905                   4
# 4          1             1  20.999767                   4

# %%
df1.groupby('Gender')['wakeup_habit'].count().plot(kind='bar')
plt.ylabel('wakeup_habit')
plt.show()

# %%
grouped = df1.groupby('Gender')
Female = grouped.get_group(1.0).loc[:,'BMI'].values
Male = grouped.get_group(2.0).loc[:,'BMI'].values
impatient_rangeF =  grouped.get_group(1.0).loc[:,'Height'].values
impatient_rangeM =  grouped.get_group(2.0).loc[:,'Height'].values
plt.scatter(impatient_rangeF, Female, color='r',marker='x')
plt.scatter(impatient_rangeM, Male, color='y',marker='o')
plt.xlabel('BMI')
plt.ylabel('wakeup_habit')
plt.show()

# %%
df1['Total']=df1['fastfood_frequency']+df1['excercise']+ df1['wakeup_habit']
df1.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight  fastfood_frequency  \
# 0           0  151340905.0       1  1.585000    58.0                   1
# 1           1  151341043.0       2  1.767800    70.0                   1
# 2           2  151340925.0       2  1.645900    60.0                   2
# 3           3  151340898.0       1  1.676400    60.0                   1
# 4           4  151341027.0       2  1.825752    70.0                   3
#
#    excercise  wakeup_habit        BMI  Physical_Condition  Total
# 0          1             1  23.087104                   4      3
# 1          1             1  22.399163                   4      3
# 2          2             3  22.148502                   4      7
# 3          1             1  21.349905                   4      3
# 4          1             1  20.999767                   4      5

# %%
sns.lmplot( x="Total", y="Physical_Condition", data=df1, fit_reg=False, legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv('output.csv')
df1.head()
# Out:
#    Unnamed: 0           id  Gender    Height  Weight  fastfood_frequency  \
# 0           0  151340905.0       1  1.585000    58.0                   1
# 1           1  151341043.0       2  1.767800    70.0                   1
# 2           2  151340925.0       2  1.645900    60.0                   2
# 3           3  151340898.0       1  1.676400    60.0                   1
# 4           4  151341027.0       2  1.825752    70.0                   3
#
#    excercise  wakeup_habit        BMI  Physical_Condition
# 0          1             1  23.087104                   4
# 1          1             1  22.399163                   4
# 2          2             3  22.148502                   4
# 3          1             1  21.349905                   4
# 4          1             1  20.999767                   4

# %%
Gender = {2: 'Male', 1 : 'Female'} 
df1.Gender= [Gender[item] for item in df1.Gender] 
df1.tail(10)
# Out:
#     Unnamed: 0           id  Gender    Height  Weight  fastfood_frequency  \
# 65          69  151340903.0    Male  1.706880    68.0                   2
# 66          70  151340894.0    Male  1.828800    73.0                   1
# 67          71  151340920.0    Male  1.676400    82.0                   1
# 68          72  151341022.0    Male  1.825752    50.0                   1
# 69          73  131440910.0  Female  1.615000    42.0                   1
# 70          74  141340900.0    Male  1.767840    70.0                   1
# 71          75  121440946.0    Male  1.825752    90.0                   2
# 72          76  141440962.0    Male  1.706880    64.0                   1
# 73          77  151340904.0    Male  1.786450    67.0                   2
# 74          78  151340916.0    Male  1.706880    55.0                   3
#
#     excercise  wakeup_habit        BMI  Physical_Condition
# 65          2             1  23.340112                   4
# ...

# %%
df1.to_csv('output.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df1=pd.read_csv('output.csv')
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1           id  Gender    Height  Weight  \
# 0           0             0  151340905.0  Female  1.585000    58.0
# 1           1             1  151341043.0    Male  1.767800    70.0
# 2           2             2  151340925.0    Male  1.645900    60.0
# 3           3             3  151340898.0  Female  1.676400    60.0
# 4           4             4  151341027.0    Male  1.825752    70.0
#
#    fastfood_frequency  excercise  wakeup_habit        BMI  Physical_Condition
# 0                   1          1             1  23.087104                   4
# 1                   1          1             1  22.399163                   4
# 2                   2          2             3  22.148502                   4
# 3                   1          1             1  21.349905                   4
# 4                   3          1             1  20.999767                   4

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)
df1.head()
# Out:
#    Unnamed: 0.1           id  Gender    Height  Weight  fastfood_frequency  \
# 0             0  151340905.0  Female  1.585000    58.0                   1
# 1             1  151341043.0    Male  1.767800    70.0                   1
# 2             2  151340925.0    Male  1.645900    60.0                   2
# 3             3  151340898.0  Female  1.676400    60.0                   1
# 4             4  151341027.0    Male  1.825752    70.0                   3
#
#    excercise  wakeup_habit        BMI  Physical_Condition
# 0          1             1  23.087104                   4
# 1          1             1  22.399163                   4
# 2          2             3  22.148502                   4
# 3          1             1  21.349905                   4
# 4          1             1  20.999767                   4

# %%
df1.drop('Unnamed: 0.1',axis=1,inplace=True)
df1.head()
# Out:
#             id  Gender    Height  Weight  fastfood_frequency  excercise  \
# 0  151340905.0  Female  1.585000    58.0                   1          1
# 1  151341043.0    Male  1.767800    70.0                   1          1
# 2  151340925.0    Male  1.645900    60.0                   2          2
# 3  151340898.0  Female  1.676400    60.0                   1          1
# 4  151341027.0    Male  1.825752    70.0                   3          1
#
#    wakeup_habit        BMI  Physical_Condition
# 0             1  23.087104                   4
# 1             1  22.399163                   4
# 2             3  22.148502                   4
# 3             1  21.349905                   4
# 4             1  20.999767                   4

# %%
df=df1[['fastfood_frequency','excercise','wakeup_habit','BMI','Physical_Condition']]
df.head()
# Out:
#    fastfood_frequency  excercise  wakeup_habit        BMI  Physical_Condition
# 0                   1          1             1  23.087104                   4
# 1                   1          1             1  22.399163                   4
# 2                   2          2             3  22.148502                   4
# 3                   1          1             1  21.349905                   4
# 4                   3          1             1  20.999767                   4

# %%
sns.regplot(x=df['BMI'],y=df['wakeup_habit'],fit_reg=False)

# %%
sns.regplot(x=df['Physical_Condition'],y=df['wakeup_habit'],fit_reg=False)

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)
df1.head()
# Out:
#    fastfood_frequency  excercise  wakeup_habit        BMI  Physical_Condition  \
# 0                   1          1             1  23.087104                   4
# 1                   1          1             1  22.399163                   4
# 2                   2          2             3  22.148502                   4
# 3                   1          1             1  21.349905                   4
# 4                   3          1             1  20.999767                   4
#
#    Gender
# 0  Female
# 1    Male
# 2    Male
# 3  Female
# 4    Male

# %%
sns.pairplot(df,kind='scatter',hue='Gender')
plt.show()

# %%
names=['fastfood_frequency','excercise,wakeup_habit','BMI']
correlations = df.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,3,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()
